# %%
# %pip install pandas scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
nba_data = pd.read_csv('data/out.csv')

X = nba_data.drop(['PTS'], axis=1)
y = nba_data['PTS']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=19)
X_train
# Out:
#         PlayerID  TeamID  OpponentID  Location  Playoffs  WinOrLoss  Starter  \
# 23816       3441       6          22         0         0          0        0
# 13600       1754       6           5         0         0          0        1
# 20806       4348       2          35         1         0          0        1
# 67675       3893       2          36         1         0          1        0
# 27936       1559       6          24         1         0          1        0
# ...          ...     ...         ...       ...       ...        ...      ...
# 17738       2037      17          16         0         1          1        0
# 39220     119815      15          17         1         0          0        0
# 164883      1825      23          22         1         0          1        1
# 99682       3572       5          16         1         0          1        1
# 82677   54022359       1          27         0         0          0        0
#
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(random_state=13, n_jobs=-1, verbose=True)

rfr.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    6.8s finished
# RandomForestRegressor(n_jobs=-1, random_state=13, verbose=True)

# %%
y_pred = rfr.predict(X_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.1s finished

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

# %%
float(mean_absolute_error(y_pred, y_test))
# Out:
# 0.01359674287866934

# %%
float(mean_squared_error(y_pred, y_test))
# Out:
# 0.021107632791445712

# %%
float(r2_score(y_pred, y_test))
# Out:
# 0.9997467623864458

# %%
params = {
    'n_estimators' : [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split' : [2, 5, 10],
    'min_samples_leaf' : [1, 2, 4]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
rfr_cv = GridSearchCV(estimator=rfr, param_grid=params, scoring="neg_mean_squared_error", n_jobs=-1, verbose=True)

# %%
rfr_cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   17.7s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   17.4s
# ...
